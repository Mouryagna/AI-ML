# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')
os.environ['LANGCHAIN_API_KEY'] = os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_TRACING_V2']="true"
os.environ['LANGCHAIN_PROJECT']='LANGCHAIN_PROJECT'

# %% [markdown]
# ### Using OPENAI

# %%
from langchain_openai import ChatOpenAI

llm=ChatOpenAI(model="gpt-4o-mini",temperature=0)
llm
# Out:
# ChatOpenAI(output_version=None, profile={'name': 'GPT-4o mini', 'release_date': '2024-07-18', 'last_updated': '2024-07-18', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000001A02CF819F0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001A02D7EE020>, root_client=<openai.OpenAI object at 0x000001A0012E84F0>, root_async_client=<openai.AsyncOpenAI object at 0x000001A02CF827A0>, model_name='gpt-4o-mini', temperature=0.0, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True, stream_chunk_timeout=120.0)

# %%
result=llm.invoke("What is GenAI")

# %%
result
# Out:
# AIMessage(content="GenAI, short for Generative AI, refers to a class of artificial intelligence models and systems that are designed to generate new content, data, or information based on the patterns and structures learned from existing data. This can include text, images, music, and other forms of media. Generative AI leverages techniques such as deep learning, particularly neural networks, to create outputs that can mimic human-like creativity and expression.\n\nSome common applications of Generative AI include:\n\n1. **Text Generation**: Models like OpenAI's GPT (Generative Pre-trained Transformer) can generate coherent and contextually relevant text, making them useful for applications like chatbots, content creation, and language translation.\n\n2. **Image Generation**: Tools like DALL-E and GANs (Generative Adversarial Networks) can create realistic images from textual descriptions or generate new images that resemble a given dataset.\n\n3. **Music Composition**: AI systems can compose original music by learning from existing compositions and styles.\n\n4. **Video Generation**: Some advanced models can generate video content or manipulate existing videos in creative ways.\n\n5. **Data Augmentation**: Generative AI can create synthetic data to augment training datasets, which is particularly useful in scenarios where real data is scarce or difficult to obtain.\n\nGenerative AI has significant implications across various fields, including entertainment, marketing, education, and more, but it also raises ethical considerations regarding authenticity, copyright, and the potential for misuse.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 294, 'prompt_tokens': 11, 'total_tokens': 305, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_03ddaa0cca', 'id': 'chatcmpl-DiigaMwcGBE9nEPbXBrpYsEhigakN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e557a-da1b-74d3-986e-489f62751bd2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 294, 'total_tokens': 305, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate(
    [
        ("system","You are an expert AI Teacher, Provide me answers based on the questions"),
        ('user',f'{input}')
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=[], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Teacher, Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='<bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001A07FD56FE0>>'), additional_kwargs={})])

# %%
chain = prompt | llm
response=chain.invoke({"input": "Can you tell me about langsmith?"})
response
# Out:
# AIMessage(content='It looks like you\'ve encountered a representation of a method in a Jupyter Notebook or IPython environment. The `raw_input` method is typically used to read input from the user. However, in Python 3, `raw_input` has been replaced by `input`. \n\nIf you are trying to get user input in a Jupyter Notebook, you can use the `input()` function directly. Here’s an example of how to use it:\n\n```python\nuser_input = input("Please enter something: ")\nprint("You entered:", user_input)\n```\n\nIf you have a specific question or need help with a particular aspect of using input in Python, feel free to ask!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 136, 'prompt_tokens': 55, 'total_tokens': 191, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_5334d4fbca', 'id': 'chatcmpl-Diik0RtYeFwtqHrrS7CTEIOB8HQgM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e557e-1930-7611-aceb-423bf52643d9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 55, 'output_tokens': 136, 'total_tokens': 191, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser=StrOutputParser()
chain = prompt | llm | output_parser

# %%
response=chain.invoke({"input":"What is GenAI?"})
response
# Out:
# 'It looks like you\'ve encountered a representation of a method in a Jupyter Notebook or IPython environment. The output you see is indicating that the `raw_input` method of the `Kernel` class is being referenced, but it is not being called or executed.\n\nIn Python 2, `raw_input()` is a built-in function that reads a line from input, while in Python 3, it has been replaced by `input()`. If you\'re using a Jupyter Notebook with Python 3, you should use `input()` instead.\n\nIf you intended to get user input, you would typically call the method like this:\n\n```python\nuser_input = input("Please enter something: ")\n```\n\nIf you have a specific question or need further assistance, feel free to ask!'
