# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### OpenAI Embeddings

# %%
os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings

embeddings=OpenAIEmbeddings(model='text_embedding-3-large')

text="This is a tutorial on OpenAI Embeddings"

# %%
query_result=embeddings.embed_query(text)

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader('./data/file.txt')
docs=loader.load()
docs
# Out:
# [Document(metadata={'source': './data/file.txt'}, page_content='Discipline beats motivation every single time. Motivation is emotional, unreliable, and fades quickly. Discipline is boring, repetitive, and brutally effective. People who wait to feel inspired waste years. People who act on schedule build results. Progress comes from showing up when you are tired, confused, or bored. Talent helps, but consistency compounds faster. Set clear goals, remove distractions, track inputs, not fantasies. Sleep properly, train regularly, study daily, and review weekly. If your plan sounds exciting, it is probably weak. If it sounds dull, measurable, and uncomfortable, it is likely correct. Most people ignore this truth and stay average forever.')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
splitter=RecursiveCharacterTextSplitter(chunk_size=300,chunk_overlap=50)
final_docs=splitter.split_documents(docs)
final_docs
# Out:
# [Document(metadata={'source': './data/file.txt'}, page_content='Discipline beats motivation every single time. Motivation is emotional, unreliable, and fades quickly. Discipline is boring, repetitive, and brutally effective. People who wait to feel inspired waste years. People who act on schedule build results. Progress comes from showing up when you are tired,'),
#  Document(metadata={'source': './data/file.txt'}, page_content='comes from showing up when you are tired, confused, or bored. Talent helps, but consistency compounds faster. Set clear goals, remove distractions, track inputs, not fantasies. Sleep properly, train regularly, study daily, and review weekly. If your plan sounds exciting, it is probably weak. If it'),
#  Document(metadata={'source': './data/file.txt'}, page_content='plan sounds exciting, it is probably weak. If it sounds dull, measurable, and uncomfortable, it is likely correct. Most people ignore this truth and stay average forever.')]

# %%
from langchain_community.vectorstores import chroma

db=chroma.from_documents(final_docs,embeddings)

# %%
query="THIS IS ME"

retrived_result=db.similarity_search(query)
print(retrived_result)

# %% [markdown]
# ### OLLAMA Embeddings

# %%
from langchain_community.embeddings import OllamaEmbeddings

embeddings=OllamaEmbeddings(model='llama3.1')
embeddings
# Out:
# C:\Users\moury\AppData\Local\Temp\ipykernel_3124\1653819237.py:3: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embeddings=OllamaEmbeddings(model='llama3.1')
# OllamaEmbeddings(base_url='http://localhost:11434', model='llama3.1', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1=embeddings.embed_documents(['Hello, This is your reward Money','Hello, How can I help you'])
r1
# Out:
# [[-0.601764976978302,
#   -0.7346604466438293,
#   2.257396697998047,
#   -0.0841122418642044,
#   1.9572728872299194,
#   0.40973135828971863,
#   1.6662384271621704,
#   0.019108392298221588,
#   -1.9637470245361328,
#   -1.3940722942352295,
#   2.667654275894165,
#   1.6708426475524902,
#   1.202162504196167,
#   0.7933446168899536,
#   -0.5011279582977295,
#   1.5963772535324097,
#   0.5895086526870728,
#   0.9993811249732971,
#   -1.377447485923767,
#   -1.969111680984497,
#   -1.7494750022888184,
#   0.2129470556974411,
#   -0.303982675075531,
#   -0.2557792067527771,
#   0.0191600751131773,
#   -1.577604055404663,
#   2.008298397064209,
#   0.056926753371953964,
#   -2.1316311359405518,
#   1.6317538022994995,
#   -2.3523998260498047,
#   1.3220380544662476,
#   -0.5593423247337341,
#   1.5031287670135498,
#   -2.980271100997925,
#   -1.8163702487945557,
#   3.949921131134033,
#   -1.8588933944702148,
#   1.9185137748718262,
#   -0.6207789182662964,
#   0.6445727348327637,
# ...

# %%
len(r1[0])
# Out:
# 4096

# %% [markdown]
# ### HuggingFace Embeddings

# %%
os.environ['HF_TOKEN']=os.getenv('HF_TOKEN')

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings=HuggingFaceEmbeddings(model_name='all-miniLM-L6-V2')
text="This is a tutorial on HuggingFace Embeddings"
query_res=embeddings.embed_query(text)
print(query_res)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ...

# %%
docs=embeddings.embed_documents([text,"This is not a tutorial on HuggingFace Embeddings"])
docs
# Out:
# [[-0.031929027289152145,
#   0.009488901123404503,
#   0.06267821788787842,
#   -0.0044907694682478905,
#   0.03742508962750435,
#   0.033300649374723434,
#   -0.047436296939849854,
#   -0.08856824040412903,
#   0.005298913922160864,
#   0.0022563827224075794,
#   0.021452559158205986,
#   -0.03324376791715622,
#   0.02029060758650303,
#   0.021964766085147858,
#   0.047561369836330414,
#   0.027817627415060997,
#   -0.006317536346614361,
#   0.07206571847200394,
#   0.005147445946931839,
#   0.0731617882847786,
#   -0.041626375168561935,
#   -0.005543143022805452,
#   0.0491110123693943,
#   -0.1000831201672554,
#   -0.009849851951003075,
#   0.0033287068363279104,
#   -0.0035966155119240284,
#   0.0441460981965065,
#   0.13875949382781982,
#   -0.01985917240381241,
#   0.0019458909519016743,
#   -0.03917333111166954,
#   0.012914796359837055,
#   0.0427246019244194,
#   -0.06779476255178452,
#   0.08192221075296402,
#   0.030818704515695572,
#   0.06798392534255981,
# ...
