# %% [markdown]
# ### Recursive Text Splitter

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_load=TextLoader('./data/file.txt').load()

text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)

# %%
docs=text_splitter.split_documents(text_load)
docs
# Out:
# [Document(metadata={'source': './data/file.txt'}, page_content='Discipline beats motivation every single time. Motivation is emotional, unreliable, and fades quickly. Discipline is boring, repetitive, and brutally effective. People who wait to feel inspired waste years. People who act on schedule build results. Progress comes from showing up when you are tired, confused, or bored. Talent helps, but consistency compounds faster. Set clear goals, remove distractions, track inputs, not fantasies. Sleep properly, train regularly, study daily, and review weekly.'),
#  Document(metadata={'source': './data/file.txt'}, page_content='train regularly, study daily, and review weekly. If your plan sounds exciting, it is probably weak. If it sounds dull, measurable, and uncomfortable, it is likely correct. Most people ignore this truth and stay average forever.')]

# %%
speech=""
with open('./data/prac.txt','r') as f:
    speech=f.read()

text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
text=text_splitter.create_documents([speech])
text
# Out:
# [Document(metadata={}, page_content='Once there was a small town at the edge of a wide plain. The town was quiet, almost forgotten, and people there lived slow lives. Every morning the sun rose gently, and every evening it went down behind the same old trees. Nothing dramatic ever happened, and that was exactly how the people liked it.'),
#  Document(metadata={}, page_content='In this town lived a young man named Arin. He was not special in any obvious way. He was not the strongest, not the smartest, and not the richest. He worked at a small repair shop where he fixed broken clocks, radios, and old machines that most people had already given up on. Arin liked broken things. They made sense to him. When something was broken, there was always a reason.'),
# ...

# %% [markdown]
# ### Character Text Splitter

# %%
from langchain_text_splitters import CharacterTextSplitter

docs=TextLoader('./data/prac.txt').load()
text_splitter=CharacterTextSplitter(separator="\n\n", chunk_size=500,chunk_overlap=50)
text=text_splitter.split_documents(docs)
text
# Out:
# [Document(metadata={'source': './data/prac.txt'}, page_content='Once there was a small town at the edge of a wide plain. The town was quiet, almost forgotten, and people there lived slow lives. Every morning the sun rose gently, and every evening it went down behind the same old trees. Nothing dramatic ever happened, and that was exactly how the people liked it.'),
#  Document(metadata={'source': './data/prac.txt'}, page_content='In this town lived a young man named Arin. He was not special in any obvious way. He was not the strongest, not the smartest, and not the richest. He worked at a small repair shop where he fixed broken clocks, radios, and old machines that most people had already given up on. Arin liked broken things. They made sense to him. When something was broken, there was always a reason.'),
# ...

# %%
speech=""
with open('./data/prac.txt','r') as f:
    speech=f.read()

text=text_splitter.create_documents([speech])
text[0].page_content
# Out:
# 'Once there was a small town at the edge of a wide plain. The town was quiet, almost forgotten, and people there lived slow lives. Every morning the sun rose gently, and every evening it went down behind the same old trees. Nothing dramatic ever happened, and that was exactly how the people liked it.'

# %% [markdown]
# ### HTML Splitter

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

html_string="""
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>DRAGONWORLD — Enter the Realm</title>
<link href="https://fonts.googleapis.com/css2?family=Cinzel+Decorative:wght@400;700;900&family=Crimson+Pro:ital,wght@0,300;0,400;1,300&display=swap" rel="stylesheet">
<style>
  *{margin:0;padding:0;box-sizing:border-box}
  :root{
    --fire1:#ff4500;--fire2:#ff8c00;--fire3:#ffd700;--fire4:#ff6b00;
    --dark:#0a0305;--deep:#130810;--mid:#1a0a12;
    --gold:#c9a227;--gold2:#e8c547;
    --scale1:#1a3a1a;--scale2:#0d2b0d;
  }
  html{scroll-behavior:smooth}
  body{
    background:var(--dark);
    font-family:'Crimson Pro',serif;
    color:#e8d5b0;
    overflow-x:hidden;
    cursor:none;
  }

  /* ===== CUSTOM DRAGON CURSOR ===== */
  #cursor-dragon{
    position:fixed;top:0;left:0;
    width:130px;height:100px;
    pointer-events:none;
    z-index:9999;
    transform:translate(-15px,-50px);
    transition:none;
  }
  #cursor-trail{position:fixed;top:0;left:0;pointer-events:none;z-index:9998;}
  .trail-particle{
    position:absolute;
    width:8px;height:8px;
    border-radius:50%;
    background:radial-gradient(circle,#ffd700,#ff4500,transparent);
    pointer-events:none;
    animation:trailFade 0.6s ease-out forwards;
  }
  @keyframes trailFade{
    0%{opacity:0.9;transform:scale(1)}
    100%{opacity:0;transform:scale(0.1)}
  }

  /* ===== SCROLL FIRE OVERLAY ===== */
  #fire-overlay{
    position:fixed;top:0;left:0;width:100%;height:100%;
    pointer-events:none;z-index:100;
    opacity:0;transition:opacity 0.3s;
  }
  #fire-overlay.active{opacity:1}
  .fire-particle{
    position:absolute;
    border-radius:50% 50% 20% 20%;
    animation:fireRise linear forwards;
    pointer-events:none;
  }
  @keyframes fireRise{
    0%{opacity:1;transform:scaleX(1) translateY(0) rotate(0deg)}
    50%{opacity:0.8;transform:scaleX(0.8) translateY(-60%) rotate(10deg)}
    100%{opacity:0;transform:scaleX(0.3) translateY(-120%) rotate(-10deg)}
  }

  /* ===== HERO SECTION ===== */
  #hero{
    min-height:100vh;
    display:flex;flex-direction:column;
    align-items:center;justify-content:center;
    position:relative;overflow:hidden;
    background:radial-gradient(ellipse at 50% 60%,#2a0a1a 0%,#0a0305 70%);
  }

  .stars{
    position:absolute;top:0;left:0;width:100%;height:100%;
    background-image:
      radial-gradient(1px 1px at 10% 20%,#fff8 0%,transparent 100%),
      radial-gradient(1px 1px at 30% 80%,#fff6 0%,transparent 100%),
      radial-gradient(1px 1px at 50% 10%,#fff9 0%,transparent 100%),
      radial-gradient(1px 1px at 70% 60%,#fff7 0%,transparent 100%),
      radial-gradient(1px 1px at 90% 30%,#fffa 0%,transparent 100%),
      radial-gradient(1.5px 1.5px at 20% 50%,#ffd70066 0%,transparent 100%),
      radial-gradient(1.5px 1.5px at 60% 85%,#ff450044 0%,transparent 100%);
    animation:twinkle 4s ease-in-out infinite alternate;
  }
  @keyframes twinkle{
    0%{opacity:0.6} 100%{opacity:1}
  }

  #main-dragon-svg{
    width:min(700px,90vw);
    animation:dragonHover 4s ease-in-out infinite;
    filter:drop-shadow(0 0 40px #ff450066) drop-shadow(0 0 80px #c9a22733);
    position:relative;z-index:2;
  }
  @keyframes dragonHover{
    0%,100%{transform:translateY(0px) rotate(-1deg)}
    50%{transform:translateY(-20px) rotate(1deg)}
  }

  .hero-title{
    font-family:'Cinzel Decorative',serif;
    font-size:clamp(3rem,8vw,7rem);
    font-weight:900;
    color:transparent;
    background:linear-gradient(135deg,#c9a227,#ffd700,#ff8c00,#c9a227);
    background-size:300% 300%;
    -webkit-background-clip:text;
    background-clip:text;
    animation:goldShimmer 3s ease infinite;
    text-align:center;
    letter-spacing:0.1em;
    text-shadow:none;
    position:relative;z-index:2;
    margin-bottom:0.5rem;
  }
  @keyframes goldShimmer{
    0%{background-position:0% 50%}
    50%{background-position:100% 50%}
    100%{background-position:0% 50%}
  }

  .hero-sub{
    font-size:clamp(1rem,2.5vw,1.5rem);
    color:#c9a22799;
    letter-spacing:0.4em;
    text-transform:uppercase;
    font-weight:300;
    font-style:italic;
    position:relative;z-index:2;
    margin-bottom:2rem;
  }

  .scroll-hint{
    position:absolute;bottom:2rem;left:50%;transform:translateX(-50%);
    display:flex;flex-direction:column;align-items:center;gap:0.5rem;
    color:#c9a22766;font-size:0.85rem;letter-spacing:0.3em;text-transform:uppercase;
    animation:bounce 2s ease-in-out infinite;z-index:2;
  }
  @keyframes bounce{
    0%,100%{transform:translateX(-50%) translateY(0)}
    50%{transform:translateX(-50%) translateY(10px)}
  }
  .scroll-hint::after{
    content:'';width:2px;height:40px;
    background:linear-gradient(to bottom,#c9a22766,transparent);
  }

  /* ===== FIRE BREATH SECTION ===== */
  #fire-section{
    min-height:100vh;
    background:linear-gradient(to bottom,#0a0305,#1a0505,#2a0a00,#0a0305);
    display:flex;align-items:center;justify-content:center;
    position:relative;overflow:hidden;
  }
  .fire-scene{
    width:100%;max-width:1000px;
    display:flex;flex-direction:column;align-items:center;
    position:relative;z-index:2;padding:4rem 2rem;
  }
  .fire-scene h2{
    font-family:'Cinzel Decorative',serif;
    font-size:clamp(2rem,5vw,4rem);
    color:#ff8c00;
    text-shadow:0 0 40px #ff450088;
    margin-bottom:1.5rem;text-align:center;
  }
  .fire-scene p{
    font-size:1.2rem;line-height:1.9;
    color:#e8d5b0bb;max-width:600px;text-align:center;margin-bottom:3rem;
  }
  #animated-fire{width:100%;max-height:300px}
  .lore-grid{
    display:grid;grid-template-columns:repeat(auto-fit,minmax(250px,1fr));
    gap:2rem;width:100%;margin-top:3rem;
  }
  .lore-card{
    border:1px solid #ff450033;
    background:linear-gradient(135deg,#1a050588,#0a030588);
    border-radius:12px;padding:2rem;
    transition:all 0.4s ease;
    position:relative;overflow:hidden;
  }
  .lore-card::before{
    content:'';position:absolute;
    top:-50%;left:-50%;width:200%;height:200%;
    background:radial-gradient(circle,#ff45001a 0%,transparent 70%);
    opacity:0;transition:opacity 0.4s;
  }
  .lore-card:hover{border-color:#ff8c00aa;transform:translateY(-5px);}
  .lore-card:hover::before{opacity:1}
  .lore-card h3{
    font-family:'Cinzel Decorative',serif;
    color:#ffd700;font-size:1.2rem;margin-bottom:1rem;
  }
  .lore-card p{color:#e8d5b0aa;font-size:1rem;line-height:1.8}

  /* ===== DRAGON SPECIES SECTION ===== */
  #species-section{
    min-height:100vh;
    background:linear-gradient(to bottom,#0a0305,#050a0f,#0a1a1a,#050a0f,#0a0305);
    padding:6rem 2rem;
    position:relative;overflow:hidden;
  }
  #species-section h2{
    font-family:'Cinzel Decorative',serif;
    font-size:clamp(2rem,5vw,4rem);
    color:#4af;
    text-shadow:0 0 40px #0af8;
    text-align:center;margin-bottom:4rem;
  }
  .species-grid{
    display:grid;grid-template-columns:repeat(auto-fit,minmax(280px,1fr));
    gap:2.5rem;max-width:1200px;margin:0 auto;
  }
  .species-card{
    border-radius:16px;padding:2.5rem 2rem;
    position:relative;overflow:hidden;
    transition:all 0.5s ease;cursor:pointer;
    border:1px solid transparent;
  }
  .species-card::after{
    content:'';position:absolute;inset:0;
    border-radius:16px;
    background:linear-gradient(135deg,transparent,rgba(255,255,255,0.05));
    pointer-events:none;
  }
  .species-card:hover{transform:scale(1.04) translateY(-8px)}
  .species-card.fire{
    background:linear-gradient(135deg,#2a0800,#1a0400);
    border-color:#ff450055;box-shadow:0 0 30px #ff45001a;
  }
  .species-card.fire:hover{box-shadow:0 0 60px #ff450044,0 20px 40px #0008}
  .species-card.ice{
    background:linear-gradient(135deg,#001a2a,#000d1a);
    border-color:#4af5;box-shadow:0 0 30px #0af1a;
  }
  .species-card.ice:hover{box-shadow:0 0 60px #0af3,0 20px 40px #0008}
  .species-card.forest{
    background:linear-gradient(135deg,#051a05,#020d02);
    border-color:#2d5;box-shadow:0 0 30px #2d51a;
  }
  .species-card.forest:hover{box-shadow:0 0 60px #2d53,0 20px 40px #0008}
  .species-card.shadow{
    background:linear-gradient(135deg,#0d0d1a,#05050f);
    border-color:#66f5;box-shadow:0 0 30px #66f1a;
  }
  .species-card.shadow:hover{box-shadow:0 0 60px #66f3,0 20px 40px #0008}
  .species-icon{font-size:3.5rem;margin-bottom:1rem;display:block}
  .species-card h3{
    font-family:'Cinzel Decorative',serif;
    font-size:1.4rem;margin-bottom:0.75rem;
  }
  .species-card.fire h3{color:#ff8c00}
  .species-card.ice h3{color:#7df}
  .species-card.forest h3{color:#6f6}
  .species-card.shadow h3{color:#aaf}
  .species-card p{color:#e8d5b0aa;font-size:0.95rem;line-height:1.8}
  .species-power{
    display:inline-block;margin-top:1.2rem;
    padding:0.3rem 1rem;border-radius:20px;
    font-size:0.8rem;letter-spacing:0.2em;text-transform:uppercase;
    font-family:'Cinzel Decorative',serif;
  }
  .fire .species-power{background:#ff450022;border:1px solid #ff450055;color:#ff8c00}
  .ice .species-power{background:#0af2;border:1px solid #4af5;color:#7df}
  .forest .species-power{background:#2d52;border:1px solid #2d55;color:#6f6}
  .shadow .species-power{background:#66f2;border:1px solid #66f5;color:#aaf}

  /* ===== DRAGON MOUTH PORTAL ===== */
  #portal-section{
    min-height:100vh;
    background:#000;
    display:flex;flex-direction:column;
    align-items:center;justify-content:center;
    position:relative;overflow:hidden;
    padding:4rem 2rem;
  }
  #portal-section h2{
    font-family:'Cinzel Decorative',serif;
    font-size:clamp(1.8rem,4vw,3.5rem);
    color:#ffd700;
    text-shadow:0 0 40px #ffd70066;
    text-align:center;margin-bottom:1rem;z-index:2;position:relative;
  }
  #portal-section > p{
    color:#e8d5b0aa;text-align:center;font-size:1.1rem;
    max-width:500px;z-index:2;position:relative;margin-bottom:3rem;
  }
  #dragon-mouth-portal{
    position:relative;width:min(500px,85vw);
    cursor:pointer;z-index:2;
    animation:mouthPulse 3s ease-in-out infinite;
  }
  @keyframes mouthPulse{
    0%,100%{filter:drop-shadow(0 0 30px #ff450055) drop-shadow(0 0 60px #ff450022)}
    50%{filter:drop-shadow(0 0 60px #ff450099) drop-shadow(0 0 120px #ffd70033)}
  }
  #portal-text{
    position:absolute;bottom:-3rem;left:50%;transform:translateX(-50%);
    font-family:'Cinzel Decorative',serif;
    color:#ffd700;font-size:0.9rem;letter-spacing:0.3em;
    white-space:nowrap;animation:portalPulse 2s ease infinite;
  }
  @keyframes portalPulse{
    0%,100%{opacity:0.6} 50%{opacity:1}
  }

  /* ===== PORTAL OVERLAY ===== */
  #portal-overlay{
    position:fixed;inset:0;z-index:1000;
    background:#000;opacity:0;
    pointer-events:none;transition:opacity 1s ease;
    display:flex;align-items:center;justify-content:center;
  }
  #portal-overlay.active{opacity:1;pointer-events:all}
  #portal-content{
    max-width:800px;width:90%;
    opacity:0;transition:opacity 1s ease 0.5s;
    text-align:center;padding:3rem 2rem;
  }
  #portal-overlay.active #portal-content{opacity:1}
  #portal-content h2{
    font-family:'Cinzel Decorative',serif;
    font-size:clamp(2rem,5vw,4rem);
    color:#ffd700;margin-bottom:2rem;
    text-shadow:0 0 40px #ffd70088;
  }
  #portal-content p{
    color:#e8d5b0cc;font-size:1.15rem;line-height:2;margin-bottom:2rem;
  }
  #close-portal{
    background:transparent;border:1px solid #ffd70066;
    color:#ffd700;padding:0.75rem 2rem;
    font-family:'Cinzel Decorative',serif;font-size:1rem;
    cursor:pointer;border-radius:4px;letter-spacing:0.2em;
    transition:all 0.3s;margin-top:1rem;
  }
  #close-portal:hover{background:#ffd70022;border-color:#ffd700;box-shadow:0 0 20px #ffd70044}

  /* ===== LEGENDS SECTION ===== */
  #legends-section{
    min-height:60vh;
    background:linear-gradient(to bottom,#0a0305,#1a0a1a,#0a0305);
    padding:6rem 2rem;text-align:center;
  }
  #legends-section h2{
    font-family:'Cinzel Decorative',serif;
    font-size:clamp(2rem,4vw,3rem);
    color:#c9a227;margin-bottom:3rem;
    text-shadow:0 0 30px #c9a22766;
  }
  .timeline{
    max-width:800px;margin:0 auto;
    position:relative;padding:2rem 0;
  }
  .timeline::before{
    content:'';position:absolute;left:50%;
    top:0;bottom:0;width:1px;
    background:linear-gradient(to bottom,transparent,#c9a22766,transparent);
  }
  .timeline-item{
    display:flex;margin-bottom:3rem;
    opacity:0;transform:translateX(-30px);
    transition:all 0.6s ease;
  }
  .timeline-item.visible{opacity:1;transform:translateX(0)}
  .timeline-item:nth-child(even){flex-direction:row-reverse;transform:translateX(30px)}
  .timeline-item:nth-child(even).visible{transform:translateX(0)}
  .timeline-content{
    width:45%;padding:1.5rem;
    border:1px solid #c9a22733;
    background:linear-gradient(135deg,#1a0a1a88,#0a050a88);
    border-radius:8px;
  }
  .timeline-content h3{
    font-family:'Cinzel Decorative',serif;
    color:#ffd700;font-size:1rem;margin-bottom:0.5rem;
  }
  .timeline-content p{color:#e8d5b0aa;font-size:0.9rem;line-height:1.7}
  .timeline-dot{
    width:12px;height:12px;border-radius:50%;
    background:#c9a227;box-shadow:0 0 10px #c9a22788;
    align-self:center;flex-shrink:0;margin:0 auto;position:relative;z-index:2;
  }

  /* ===== FOOTER ===== */
  footer{
    padding:3rem 2rem;text-align:center;
    background:#050103;
    border-top:1px solid #c9a22722;
  }
  footer p{color:#c9a22766;font-size:0.9rem;letter-spacing:0.2em}

  /* ===== FLOATING EMBERS ===== */
  .ember{
    position:fixed;pointer-events:none;
    border-radius:50%;
    background:radial-gradient(circle,#ffd700,#ff4500,transparent);
    animation:emberFloat linear infinite;
    z-index:5;
  }
  @keyframes emberFloat{
    0%{transform:translateY(100vh) translateX(0) scale(1);opacity:0.8}
    50%{opacity:0.5}
    100%{transform:translateY(-20px) translateX(var(--drift)) scale(0.2);opacity:0}
  }

  /* Scroll reveal */
  .reveal{opacity:0;transform:translateY(40px);transition:all 0.8s ease}
  .reveal.visible{opacity:1;transform:translateY(0)}

  /* Waving dragon paw */
  .wave-arm{
    transform-origin:50% 100%;
    animation:wave 0.4s ease-in-out;
  }
  @keyframes wave{
    0%{transform:rotate(0deg)}
    25%{transform:rotate(20deg)}
    75%{transform:rotate(-15deg)}
    100%{transform:rotate(0deg)}
  }
</style>
</head>
<body>

<!-- Dragon cursor -->
<div id="cursor-dragon">
  <svg viewBox="0 0 120 90" xmlns="http://www.w3.org/2000/svg" id="cursor-svg">
    <defs>
      <linearGradient id="cBodyGrad" x1="0%" y1="0%" x2="100%" y2="100%">
        <stop offset="0%" stop-color="#c0392b"/>
        <stop offset="50%" stop-color="#922b21"/>
        <stop offset="100%" stop-color="#641e16"/>
      </linearGradient>
      <linearGradient id="cWingGrad" x1="0%" y1="0%" x2="100%" y2="100%">
        <stop offset="0%" stop-color="#7b241c"/>
        <stop offset="100%" stop-color="#2c0b0b"/>
      </linearGradient>
    </defs>

    <!-- === WING (behind body) === -->
    <!-- Main wing membrane stretching up-right -->
    <path d="M68 38 C80 20, 100 8, 112 4 C105 14, 98 20, 95 28 C108 14, 118 18, 116 26 C110 24, 102 28, 96 36 C106 26, 112 32, 108 40 C100 36, 88 40, 80 48 Z"
          fill="url(#cWingGrad)" opacity="0.95"/>
    <!-- Wing membrane lower lobe -->
    <path d="M72 48 C82 52, 98 58, 108 68 C96 62, 84 60, 76 56 Z"
          fill="#5a1a1a" opacity="0.8"/>
    <!-- Wing bone lines -->
    <line x1="68" y1="38" x2="112" y2="4" stroke="#8b2020" stroke-width="1" opacity="0.7"/>
    <line x1="68" y1="38" x2="116" y2="26" stroke="#8b2020" stroke-width="0.8" opacity="0.6"/>
    <line x1="68" y1="38" x2="108" y2="40" stroke="#8b2020" stroke-width="0.8" opacity="0.6"/>
    <line x1="72" y1="48" x2="108" y2="68" stroke="#8b2020" stroke-width="0.8" opacity="0.5"/>

    <!-- === TAIL === -->
    <path id="cursor-tail"
          d="M84 58 C92 62, 100 66, 106 72 C110 76, 112 80, 109 84 C107 80, 104 76, 100 74 C96 78, 96 82, 98 86 C94 82, 91 76, 95 70 C88 68, 80 62, 76 56 Z"
          fill="url(#cBodyGrad)"/>
    <!-- Tail spikes -->
    <path d="M98 86 L102 82 L106 86 Z" fill="#ff6b00"/>
    <path d="M106 76 L110 72 L113 77 Z" fill="#ff6b00"/>

    <!-- === BODY === -->
    <!-- Main torso - elongated dragon body -->
    <path d="M32 30 C42 22, 60 20, 72 26 C82 30, 86 40, 84 52 C82 62, 72 66, 60 64 C48 62, 36 56, 30 46 C26 38, 28 34, 32 30 Z"
          fill="url(#cBodyGrad)"/>
    <!-- Belly lighter scales -->
    <path d="M36 38 C44 32, 58 30, 68 36 C76 40, 78 50, 72 56 C64 62, 48 60, 40 52 C34 46, 32 42, 36 38 Z"
          fill="#c0392b" opacity="0.4"/>

    <!-- === NECK === -->
    <path d="M32 30 C28 24, 22 20, 18 18 C22 22, 24 28, 26 34 Z"
          fill="url(#cBodyGrad)"/>

    <!-- === HEAD === -->
    <!-- Skull/cranium -->
    <path d="M6 22 C8 14, 16 10, 24 12 C30 14, 32 20, 30 26 C28 32, 20 34, 14 30 C8 28, 6 26, 6 22 Z"
          fill="url(#cBodyGrad)"/>
    <!-- Head top ridge / frill -->
    <path d="M10 14 L8 6 L13 12 L16 4 L20 11 L24 6 L26 13"
          fill="none" stroke="#ff6b00" stroke-width="1.5" stroke-linejoin="round"/>
    <!-- Forehead horn -->
    <path d="M22 10 L26 2 L28 10 Z" fill="#8b0000"/>
    <!-- Secondary horn -->
    <path d="M16 11 L19 4 L22 11 Z" fill="#7a0000"/>

    <!-- === SNOUT / JAW === -->
    <!-- Upper jaw - long pointed snout -->
    <path d="M6 22 C4 20, 0 20, -4 22 C-2 24, 2 25, 6 26 Z"
          fill="#a93226"/>
    <!-- Lower jaw open slightly -->
    <path d="M6 26 C4 26, 0 27, -3 26 C-1 29, 3 30, 7 28 Z"
          fill="#8b0000"/>
    <!-- Teeth upper -->
    <path d="M2 25 L0 28 L3 26 Z" fill="#f0e6d3"/>
    <path d="M-1 25 L-3 29 L0 26 Z" fill="#f0e6d3"/>
    <!-- Teeth lower -->
    <path d="M1 27 L-1 24 L2 26 Z" fill="#e8d5b0" opacity="0.8"/>
    <!-- Nostril -->
    <ellipse cx="-1" cy="22" rx="1.2" ry="0.8" fill="#5a0000"/>

    <!-- Fire breath from mouth -->
    <g id="cursor-flame">
      <path d="M-4 24 C-10 22, -18 20, -24 23 C-18 23, -12 24, -8 26 Z"
            fill="#ff4500" opacity="0.9"/>
      <path d="M-4 24 C-12 21, -20 18, -28 20 C-20 22, -12 23, -6 26 Z"
            fill="#ff8c00" opacity="0.7"/>
      <path d="M-4 25 C-14 23, -24 22, -30 25 C-22 24, -14 25, -7 27 Z"
            fill="#ffd700" opacity="0.5"/>
    </g>

    <!-- === EYE === -->
    <ellipse cx="20" cy="18" rx="4.5" ry="4" fill="#1a0000"/>
    <ellipse cx="20" cy="18" rx="3.5" ry="3.5" fill="#ffd700"/>
    <!-- Vertical slit pupil -->
    <ellipse cx="20" cy="18" rx="1.2" ry="2.8" fill="#000"/>
    <!-- Eye gleam -->
    <ellipse cx="18.5" cy="16.5" rx="1" ry="0.8" fill="#fff" opacity="0.7"/>
    <!-- Brow ridge -->
    <path d="M16 14 C18 12, 22 12, 25 14" stroke="#7a0000" stroke-width="1.5" fill="none" stroke-linecap="round"/>

    <!-- === SPINE DORSAL SPIKES === -->
    <path d="M30 26 L28 18 L33 26 L36 16 L40 25 L44 15 L47 24 L51 14 L54 24 L58 16 L61 25 L65 18 L68 28"
          fill="#ff4500" stroke="#cc2200" stroke-width="0.5"/>

    <!-- === FRONT LEGS === -->
    <g id="cursor-arm">
      <!-- Front leg left -->
      <path d="M38 60 C36 66, 34 72, 32 76" stroke="#a93226" stroke-width="3.5" fill="none" stroke-linecap="round"/>
      <!-- Claws -->
      <path d="M32 76 L28 80 M32 76 L31 82 M32 76 L35 80" stroke="#c0392b" stroke-width="1.5" stroke-linecap="round" fill="none"/>
    </g>
    <!-- Back leg -->
    <path d="M62 62 C64 68, 66 72, 65 76" stroke="#922b21" stroke-width="3" fill="none" stroke-linecap="round"/>
    <path d="M65 76 L62 80 M65 76 L65 82 M65 76 L68 79" stroke="#922b21" stroke-width="1.2" stroke-linecap="round" fill="none"/>

    <!-- Scale texture hints on body -->
    <g fill="none" stroke="#7b1d1d" stroke-width="0.6" opacity="0.5">
      <path d="M44 34 Q50 30 56 34 Q50 38 44 34Z"/>
      <path d="M52 28 Q58 24 64 28 Q58 32 52 28Z"/>
      <path d="M46 44 Q52 40 58 44 Q52 48 46 44Z"/>
      <path d="M58 38 Q64 34 70 38 Q64 42 58 38Z"/>
    </g>
  </svg>
</div>
<div id="cursor-trail"></div>

<!-- Fire overlay -->
<div id="fire-overlay"></div>

<!-- Portal overlay -->
<div id="portal-overlay">
  <div id="portal-content">
    <h2>Inside the Dragon's Realm</h2>
    <p>
      You have passed beyond the veil of mortal sight, drawn into the ancient heart of dragonkind.
      Here, fire is not destruction — it is creation. The pulse of dragon breath carved the first mountains,
      boiled the first seas, breathed warmth into the first stars.
    </p>
    <p>
      In this place, time bends like flame in wind. Civilizations rise and crumble in the span of a dragon's dream.
      Their hoard is not gold — it is memory itself, each coin a story, each gem a century of living.
    </p>
    <p>
      You are a guest here. Move slowly. Speak softly. And never, never forget —
      they are not monsters. They are the oldest gods, still breathing.
    </p>
    <button id="close-portal">↩ Return to the World</button>
  </div>
</div>

<!-- ===== HERO ===== -->
<section id="hero">
  <div class="stars"></div>

  <svg id="main-dragon-svg" viewBox="0 0 700 450" xmlns="http://www.w3.org/2000/svg">
    <defs>
      <radialGradient id="bodyGrad" cx="50%" cy="50%" r="50%">
        <stop offset="0%" stop-color="#8b0000"/>
        <stop offset="100%" stop-color="#3d0000"/>
      </radialGradient>
      <radialGradient id="wingGrad" cx="30%" cy="30%" r="70%">
        <stop offset="0%" stop-color="#6b0000"/>
        <stop offset="100%" stop-color="#1a0000"/>
      </radialGradient>
      <radialGradient id="eyeGrad" cx="40%" cy="40%" r="60%">
        <stop offset="0%" stop-color="#ffd700"/>
        <stop offset="60%" stop-color="#ff8c00"/>
        <stop offset="100%" stop-color="#ff4500"/>
      </radialGradient>
      <radialGradient id="flameGrad" cx="30%" cy="80%" r="70%">
        <stop offset="0%" stop-color="#fff"/>
        <stop offset="20%" stop-color="#ffd700"/>
        <stop offset="60%" stop-color="#ff4500"/>
        <stop offset="100%" stop-color="transparent"/>
      </radialGradient>
      <filter id="glow">
        <feGaussianBlur stdDeviation="4" result="blur"/>
        <feMerge><feMergeNode in="blur"/><feMergeNode in="SourceGraphic"/></feMerge>
      </filter>
      <filter id="fireGlow">
        <feGaussianBlur stdDeviation="8" result="blur"/>
        <feMerge><feMergeNode in="blur"/><feMergeNode in="SourceGraphic"/></feMerge>
      </filter>
    </defs>

    <!-- Left wing (back) -->
    <path d="M310 180 Q220 60 100 30 Q160 90 200 160 Q130 70 80 80 Q150 130 210 190 Q140 110 100 130 Q170 160 230 210Z"
          fill="url(#wingGrad)" opacity="0.85"/>

    <!-- Right wing (back) -->
    <path d="M450 160 Q540 50 650 20 Q590 80 560 155 Q620 65 660 75 Q590 125 530 175 Q605 95 640 115 Q570 150 505 200Z"
          fill="url(#wingGrad)" opacity="0.85"/>

    <!-- Body -->
    <ellipse cx="380" cy="280" rx="140" ry="90" fill="url(#bodyGrad)"/>

    <!-- Belly scales -->
    <ellipse cx="380" cy="310" rx="80" ry="50" fill="#c8000022"/>
    <path d="M340 290 Q380 280 420 290 Q380 300 340 290Z" fill="#ff000011"/>
    <path d="M350 305 Q380 295 410 305 Q380 315 350 305Z" fill="#ff000011"/>
    <path d="M355 320 Q380 312 405 320 Q380 328 355 320Z" fill="#ff000011"/>

    <!-- Neck -->
    <path d="M290 240 Q260 200 250 170 Q280 185 310 210 Q295 200 285 180 Q305 195 320 225Z" fill="url(#bodyGrad)"/>

    <!-- Head -->
    <ellipse cx="230" cy="155" rx="60" ry="45" fill="url(#bodyGrad)"/>

    <!-- Head spines -->
    <path d="M210 115 L215 90 L222 112" fill="#8b0000"/>
    <path d="M228 108 L235 80 L240 106" fill="#8b0000"/>
    <path d="M245 112 L253 88 L257 110" fill="#8b0000"/>

    <!-- Snout / jaw -->
    <path d="M190 165 Q175 155 165 160 Q175 170 185 178 Q175 168 168 175 Q180 182 195 185 Q188 178 183 183Q195 188 210 185Q215 175 210 168Z" fill="#6b0000"/>

    <!-- Upper jaw/snout -->
    <ellipse cx="185" cy="158" rx="30" ry="18" fill="#7a0000"/>

    <!-- Nostril -->
    <ellipse cx="170" cy="156" rx="5" ry="3" fill="#3d0000"/>
    <ellipse cx="182" cy="153" rx="4" ry="2.5" fill="#3d0000"/>

    <!-- Eye socket -->
    <ellipse cx="215" cy="142" rx="16" ry="14" fill="#1a0000"/>
    <!-- Iris -->
    <ellipse cx="215" cy="142" rx="12" ry="12" fill="url(#eyeGrad)" filter="url(#glow)"/>
    <!-- Pupil (vertical slit) -->
    <ellipse cx="215" cy="142" rx="4" ry="9" fill="#000"/>
    <!-- Eye gleam -->
    <ellipse cx="211" cy="137" rx="3" ry="2" fill="#fff" opacity="0.6"/>

    <!-- Teeth (upper) -->
    <path d="M172 165 L168 175 L176 168Z" fill="#e8d5b0"/>
    <path d="M182 170 L179 181 L187 173Z" fill="#e8d5b0"/>
    <path d="M192 172 L191 183 L197 174Z" fill="#e8d5b0"/>
    <!-- Teeth (lower) -->
    <path d="M174 178 L172 168 L180 175Z" fill="#e8d5b0" opacity="0.8"/>
    <path d="M187 180 L186 170 L193 177Z" fill="#e8d5b0" opacity="0.8"/>

    <!-- FIRE BREATH -->
    <g filter="url(#fireGlow)" id="fire-breath">
      <ellipse cx="135" cy="165" rx="30" ry="12" fill="#fff" opacity="0.95"/>
      <ellipse cx="105" cy="163" rx="28" ry="11" fill="#ffd700" opacity="0.9"/>
      <ellipse cx="75" cy="160" rx="26" ry="13" fill="#ff8c00" opacity="0.8"/>
      <ellipse cx="45" cy="158" rx="24" ry="14" fill="#ff4500" opacity="0.7"/>
      <ellipse cx="18" cy="156" rx="20" ry="12" fill="#ff2200" opacity="0.5"/>
      <ellipse cx="130" cy="168" rx="18" ry="8" fill="#fff" opacity="0.7"/>
      <ellipse cx="90" cy="170" rx="22" ry="10" fill="#ffd700" opacity="0.6"/>
      <ellipse cx="50" cy="172" rx="20" ry="9" fill="#ff4500" opacity="0.4"/>
      <ellipse cx="128" cy="158" rx="15" ry="6" fill="#ffd700" opacity="0.9"/>
      <ellipse cx="100" cy="155" rx="18" ry="7" fill="#ffb300" opacity="0.7"/>
    </g>

    <!-- Front legs -->
    <path d="M310 330 Q295 370 285 400 Q295 390 308 360 Q305 385 300 410 Q312 395 318 365Z" fill="url(#bodyGrad)"/>
    <path d="M450 330 Q465 370 475 400 Q465 390 452 360 Q455 385 460 410 Q448 395 442 365Z" fill="url(#bodyGrad)"/>

    <!-- Claws front left -->
    <path d="M282 400 L275 415 L284 408Z" fill="#8b0000"/>
    <path d="M288 405 L282 420 L291 413Z" fill="#8b0000"/>
    <path d="M295 408 L290 423 L299 416Z" fill="#8b0000"/>

    <!-- Claws front right -->
    <path d="M475 400 L482 415 L473 408Z" fill="#8b0000"/>
    <path d="M469 405 L475 420 L466 413Z" fill="#8b0000"/>
    <path d="M462 408 L467 423 L458 416Z" fill="#8b0000"/>

    <!-- Back leg -->
    <path d="M490 350 Q510 385 505 415 Q497 400 498 375Z" fill="url(#bodyGrad)" opacity="0.8"/>

    <!-- Tail -->
    <path id="main-tail" d="M510 290 Q560 310 590 340 Q620 365 640 380 Q650 395 645 415 Q635 400 628 388 Q615 370 590 355 Q560 338 530 320 Q510 308 495 300Z" fill="url(#bodyGrad)"/>
    <!-- Tail spike -->
    <path d="M645 415 L660 430 L650 418 L658 420Z" fill="#6b0000"/>

    <!-- Spine ridge -->
    <path d="M280 180 L290 158 L305 178 L320 155 L338 172 L355 150 L372 168 L390 148 L405 165 L420 145 L435 162 L450 142 L462 158 L475 140 L480 165" stroke="#ff8c00" stroke-width="2" fill="none" filter="url(#glow)"/>

    <!-- Scale pattern on body -->
    <g opacity="0.25" stroke="#ff2200" stroke-width="0.5" fill="none">
      <path d="M330 260 Q350 250 370 260 Q350 270 330 260Z"/>
      <path d="M360 250 Q380 240 400 250 Q380 260 360 250Z"/>
      <path d="M390 260 Q410 250 430 260 Q410 270 390 260Z"/>
      <path d="M345 278 Q365 268 385 278 Q365 288 345 278Z"/>
      <path d="M375 270 Q395 260 415 270 Q395 280 375 270Z"/>
      <path d="M355 296 Q375 286 395 296 Q375 306 355 296Z"/>
      <path d="M385 288 Q405 278 425 288 Q405 298 385 288Z"/>
    </g>

    <!-- Wing membrane detail lines -->
    <g stroke="#6b0000" stroke-width="0.8" fill="none" opacity="0.6">
      <path d="M310 180 Q250 130 200 100"/>
      <path d="M310 185 Q245 150 195 135"/>
      <path d="M310 190 Q250 165 215 170"/>
      <path d="M450 160 Q510 110 560 85"/>
      <path d="M450 168 Q515 140 565 130"/>
      <path d="M450 176 Q510 160 555 165"/>
    </g>

    <!-- Ambient glow under dragon -->
    <ellipse cx="380" cy="420" rx="200" ry="20" fill="#ff4500" opacity="0.06"/>
  </svg>

  <h1 class="hero-title">DRAGONWORLD</h1>
  <p class="hero-sub">Enter the Ancient Realm of Fire and Scale</p>
  <div class="scroll-hint">Scroll to Descend</div>
</section>

<!-- ===== FIRE BREATH SECTION ===== -->
<section id="fire-section">
  <div class="fire-scene reveal">
    <h2>🔥 Born of Eternal Flame</h2>
    <p>Before the first sun ignited, there was dragon fire. The primordial breath that shaped continents,
       melted stone into sky, and etched the first constellations into the void.
       They are not creatures of this world — this world is a creature of theirs.</p>

    <!-- Animated fire SVG -->
    <svg id="animated-fire" viewBox="0 0 700 200" xmlns="http://www.w3.org/2000/svg">
      <defs>
        <radialGradient id="f1" cx="50%" cy="100%" r="80%">
          <stop offset="0%" stop-color="#fff"/>
          <stop offset="30%" stop-color="#ffd700"/>
          <stop offset="70%" stop-color="#ff4500"/>
          <stop offset="100%" stop-color="transparent"/>
        </radialGradient>
        <radialGradient id="f2" cx="50%" cy="100%" r="80%">
          <stop offset="0%" stop-color="#ffd700"/>
          <stop offset="50%" stop-color="#ff8c00"/>
          <stop offset="100%" stop-color="transparent"/>
        </radialGradient>
      </defs>
      <!-- Flame tongues -->
      <ellipse cx="350" cy="150" rx="80" ry="120" fill="url(#f1)" opacity="0.9">
        <animate attributeName="ry" values="120;140;110;130;120" dur="1.2s" repeatCount="indefinite"/>
        <animate attributeName="rx" values="80;70;90;75;80" dur="1.2s" repeatCount="indefinite"/>
        <animate attributeName="cy" values="150;140;155;145;150" dur="1.2s" repeatCount="indefinite"/>
      </ellipse>
      <ellipse cx="280" cy="160" rx="60" ry="90" fill="url(#f2)" opacity="0.7">
        <animate attributeName="ry" values="90;110;80;100;90" dur="0.9s" repeatCount="indefinite"/>
        <animate attributeName="cy" values="160;148;165;153;160" dur="0.9s" repeatCount="indefinite"/>
      </ellipse>
      <ellipse cx="420" cy="158" rx="55" ry="85" fill="url(#f2)" opacity="0.7">
        <animate attributeName="ry" values="85;100;75;95;85" dur="1.1s" repeatCount="indefinite"/>
        <animate attributeName="cy" values="158;145;162;150;158" dur="1.1s" repeatCount="indefinite"/>
      </ellipse>
      <ellipse cx="180" cy="168" rx="45" ry="65" fill="#ff4500" opacity="0.5">
        <animate attributeName="ry" values="65;80;55;70;65" dur="0.8s" repeatCount="indefinite"/>
        <animate attributeName="cy" values="168;155;172;160;168" dur="0.8s" repeatCount="indefinite"/>
      </ellipse>
      <ellipse cx="520" cy="165" rx="42" ry="62" fill="#ff4500" opacity="0.5">
        <animate attributeName="ry" values="62;78;52;68;62" dur="1.0s" repeatCount="indefinite"/>
        <animate attributeName="cy" values="165;152;170;157;165" dur="1.0s" repeatCount="indefinite"/>
      </ellipse>
      <ellipse cx="100" cy="175" rx="30" ry="45" fill="#ff2200" opacity="0.35">
        <animate attributeName="ry" values="45;55;38;50;45" dur="0.7s" repeatCount="indefinite"/>
      </ellipse>
      <ellipse cx="600" cy="173" rx="30" ry="45" fill="#ff2200" opacity="0.35">
        <animate attributeName="ry" values="45;58;40;52;45" dur="0.85s" repeatCount="indefinite"/>
      </ellipse>
    </svg>

    <div class="lore-grid">
      <div class="lore-card reveal">
        <h3>🌋 The Forge of Creation</h3>
        <p>Dragon fire burns at 3,000 degrees — hot enough to transmute iron into starlight. Ancient smiths sought dragon blessing to craft legendary weapons.</p>
      </div>
      <div class="lore-card reveal">
        <h3>🏔️ Hoardkeepers of Ages</h3>
        <p>A dragon's hoard is their soul made tangible. Each treasure holds a memory from the age it was collected. To steal from a hoard is to steal a piece of history.</p>
      </div>
      <div class="lore-card reveal">
        <h3>📜 The Ancient Tongue</h3>
        <p>Draconic speech carries inherent magic. To hear a dragon's true name spoken aloud causes the ground beneath to tremble and the sky to split with lightning.</p>
      </div>
    </div>
  </div>
</section>

<!-- ===== SPECIES SECTION ===== -->
<section id="species-section">
  <h2 class="reveal">The Dragon Kindreds</h2>
  <div class="species-grid">
    <div class="species-card fire reveal">
      <span class="species-icon">🔴</span>
      <h3>Crimson Inferno</h3>
      <p>The eldest and most feared of all dragonkind. Born in the heart of active volcanoes, they are creatures of pure destruction and ancient pride. Their scales absorb heat — touching one bare-handed will reduce bone to ash.</p>
      <span class="species-power">Breath: Hellfire</span>
    </div>
    <div class="species-card ice reveal">
      <span class="species-icon">🔵</span>
      <h3>Azure Glacial</h3>
      <p>Dwelling in the frozen poles, these serene leviathans can exhale blizzards that freeze armies mid-stride. They are philosophers and historians, preferring silence and observation over war.</p>
      <span class="species-power">Breath: Frostbite Storm</span>
    </div>
    <div class="species-card forest reveal">
      <span class="species-icon">🟢</span>
      <h3>Verdant Serpent</h3>
      <p>Masters of illusion and camouflage, the forest dragons blend into canopy so completely that entire civilizations have lived beneath them unknowingly for generations. Their breath accelerates growth — or decay.</p>
      <span class="species-power">Breath: Spore Miasma</span>
    </div>
    <div class="species-card shadow reveal">
      <span class="species-icon">🟣</span>
      <h3>Void Phantom</h3>
      <p>Whether these creatures exist in our world or merely pass through it is debated by scholars. Their bodies are semi-translucent, absorbing starlight. To look one in the eye is to glimpse the end of time.</p>
      <span class="species-power">Breath: Entropy Void</span>
    </div>
  </div>
</section>

<!-- ===== PORTAL SECTION ===== -->
<section id="portal-section">
  <h2>Enter the Dragon's Maw</h2>
  <p>Dare to pass beyond the teeth and discover what lies within the oldest fire...</p>

  <div id="dragon-mouth-portal">
    <svg viewBox="0 0 500 420" xmlns="http://www.w3.org/2000/svg">
      <defs>
        <radialGradient id="mawDepth" cx="50%" cy="50%" r="50%">
          <stop offset="0%" stop-color="#ff8c00"/>
          <stop offset="30%" stop-color="#c03000"/>
          <stop offset="70%" stop-color="#3d0000"/>
          <stop offset="100%" stop-color="#0a0000"/>
        </radialGradient>
        <radialGradient id="gumGrad" cx="50%" cy="50%" r="50%">
          <stop offset="0%" stop-color="#8b0000"/>
          <stop offset="100%" stop-color="#5a0000"/>
        </radialGradient>
        <filter id="portalGlow">
          <feGaussianBlur stdDeviation="6" result="blur"/>
          <feMerge><feMergeNode in="blur"/><feMergeNode in="SourceGraphic"/></feMerge>
        </filter>
      </defs>

      <!-- Outer head/jaw structure -->
      <path d="M50 200 Q80 80 250 60 Q420 80 450 200 Q430 140 250 120 Q70 140 50 200Z" fill="#4a0000"/>
      <path d="M50 200 Q80 320 250 360 Q420 320 450 200 Q430 270 250 300 Q70 270 50 200Z" fill="#3d0000"/>

      <!-- Upper teeth row -->
      <path d="M85 175 L78 220 L95 178Z" fill="#e8d5b0"/>
      <path d="M110 158 L106 208 L122 162Z" fill="#e8d5b0"/>
      <path d="M140 148 L138 200 L153 152Z" fill="#e8d5b0"/>
      <path d="M170 144 L170 196 L184 148Z" fill="#e8d5b0"/>
      <path d="M200 142 L202 194 L215 146Z" fill="#e8d5b0"/>
      <path d="M230 142 L233 194 L246 146Z" fill="#e8d5b0"/>
      <path d="M260 143 L264 195 L277 147Z" fill="#e8d5b0"/>
      <path d="M290 146 L296 198 L308 150Z" fill="#e8d5b0"/>
      <path d="M318 152 L326 203 L337 156Z" fill="#e8d5b0"/>
      <path d="M344 162 L354 213 L364 166Z" fill="#e8d5b0"/>
      <path d="M368 178 L380 226 L388 182Z" fill="#e8d5b0"/>
      <path d="M390 198 L404 242 L410 202Z" fill="#e8d5b0"/>

      <!-- Lower teeth row -->
      <path d="M90 225 L83 178 L100 222Z" fill="#e8d5b0" opacity="0.9"/>
      <path d="M115 212 L110 165 L126 209Z" fill="#e8d5b0" opacity="0.9"/>
      <path d="M143 205 L140 158 L155 202Z" fill="#e8d5b0" opacity="0.9"/>
      <path d="M172 202 L172 155 L186 199Z" fill="#e8d5b0" opacity="0.9"/>
      <path d="M202 201 L204 154 L217 198Z" fill="#e8d5b0" opacity="0.9"/>
      <path d="M232 201 L235 154 L248 198Z" fill="#e8d5b0" opacity="0.9"/>
      <path d="M262 202 L266 155 L279 199Z" fill="#e8d5b0" opacity="0.9"/>
      <path d="M292 205 L298 158 L310 202Z" fill="#e8d5b0" opacity="0.9"/>
      <path d="M320 211 L328 164 L339 208Z" fill="#e8d5b0" opacity="0.9"/>
      <path d="M346 220 L356 173 L366 217Z" fill="#e8d5b0" opacity="0.9"/>
      <path d="M370 233 L383 187 L392 230Z" fill="#e8d5b0" opacity="0.9"/>

      <!-- Throat / portal into darkness -->
      <ellipse cx="250" cy="210" rx="150" ry="80" fill="url(#mawDepth)" filter="url(#portalGlow)"/>

      <!-- Inner glow rings -->
      <ellipse cx="250" cy="210" rx="120" ry="65" fill="none" stroke="#ff4500" stroke-width="2" opacity="0.4"/>
      <ellipse cx="250" cy="210" rx="90" ry="50" fill="none" stroke="#ff8c00" stroke-width="1.5" opacity="0.5"/>
      <ellipse cx="250" cy="210" rx="60" ry="35" fill="none" stroke="#ffd700" stroke-width="1" opacity="0.6"/>
      <ellipse cx="250" cy="210" rx="30" ry="18" fill="#ffd700" opacity="0.3">
        <animate attributeName="rx" values="30;40;25;35;30" dur="1.5s" repeatCount="indefinite"/>
        <animate attributeName="ry" values="18;25;15;22;18" dur="1.5s" repeatCount="indefinite"/>
        <animate attributeName="opacity" values="0.3;0.6;0.2;0.5;0.3" dur="1.5s" repeatCount="indefinite"/>
      </ellipse>

      <!-- Tongue -->
      <path d="M180 270 Q250 290 320 270 Q280 310 250 320 Q220 310 180 270Z" fill="#8b0000"/>
      <path d="M220 318 Q250 330 280 318 Q260 340 250 345 Q240 340 220 318Z" fill="#6b0000"/>
      <path d="M235 342 L245 358 L250 345Z" fill="#5a0000"/>
      <path d="M265 342 L255 358 L250 345Z" fill="#5a0000"/>

      <!-- Gum ridges -->
      <path d="M80 215 Q250 195 420 215" stroke="#6b0000" stroke-width="3" fill="none"/>
      <path d="M80 220 Q250 200 420 220" stroke="#5a0000" stroke-width="2" fill="none" opacity="0.5"/>

      <!-- Eyes flanking -->
      <ellipse cx="95" cy="130" rx="25" ry="22" fill="#ffd700" opacity="0.9"/>
      <ellipse cx="95" cy="130" rx="8" ry="16" fill="#000"/>
      <ellipse cx="91" cy="124" rx="5" ry="3" fill="#fff" opacity="0.5"/>

      <ellipse cx="405" cy="130" rx="25" ry="22" fill="#ffd700" opacity="0.9"/>
      <ellipse cx="405" cy="130" rx="8" ry="16" fill="#000"/>
      <ellipse cx="401" cy="124" rx="5" ry="3" fill="#fff" opacity="0.5"/>

      <!-- Scales on head -->
      <g opacity="0.3" fill="none" stroke="#ff2200" stroke-width="0.5">
        <path d="M150 100 Q170 90 190 100 Q170 110 150 100Z"/>
        <path d="M175 88 Q195 78 215 88 Q195 98 175 88Z"/>
        <path d="M200 80 Q220 70 240 80 Q220 90 200 80Z"/>
        <path d="M280 88 Q300 78 320 88 Q300 98 280 88Z"/>
        <path d="M305 100 Q325 90 345 100 Q325 110 305 100Z"/>
        <path d="M225 78 Q245 68 265 78 Q245 88 225 78Z"/>
      </g>

      <!-- Horns -->
      <path d="M120 80 L100 20 L125 75" fill="#3d0000"/>
      <path d="M150 65 L140 10 L158 62" fill="#3d0000"/>
      <path d="M380 80 L400 20 L375 75" fill="#3d0000"/>
      <path d="M350 65 L360 10 L342 62" fill="#3d0000"/>
    </svg>
    <div id="portal-text">⬇ Step Inside ⬇</div>
  </div>
</section>

<!-- ===== LEGENDS TIMELINE ===== -->
<section id="legends-section">
  <h2 class="reveal">Legends Through the Ages</h2>
  <div class="timeline">
    <div class="timeline-item">
      <div class="timeline-content">
        <h3>Age of Primordial Flame</h3>
        <p>The first dragons emerged from cooling stellar matter. They were the size of mountains, older than language, older than thought.</p>
      </div>
      <div class="timeline-dot"></div>
      <div style="width:45%"></div>
    </div>
    <div class="timeline-item">
      <div style="width:45%"></div>
      <div class="timeline-dot"></div>
      <div class="timeline-content">
        <h3>The Great Conclave</h3>
        <p>Dragons gathered for the first and last time. They divided the world into territories and swore never to interfere with the rising civilizations below.</p>
      </div>
    </div>
    <div class="timeline-item">
      <div class="timeline-content">
        <h3>War of Sundered Skies</h3>
        <p>A rogue dragon broke the Conclave oath. The sky burned for forty years. Three continents were reshaped. The scar still glows at night.</p>
      </div>
      <div class="timeline-dot"></div>
      <div style="width:45%"></div>
    </div>
    <div class="timeline-item">
      <div style="width:45%"></div>
      <div class="timeline-dot"></div>
      <div class="timeline-content">
        <h3>The Long Slumber</h3>
        <p>One by one, the elder dragons retreated into mountain sleep. They dream still. What they dream of is what causes earthquakes.</p>
      </div>
    </div>
    <div class="timeline-item">
      <div class="timeline-content">
        <h3>The Awakening Foretold</h3>
        <p>Ancient prophecy speaks of a century when all dragons wake simultaneously. That century, scholars now realize, is this one.</p>
      </div>
      <div class="timeline-dot"></div>
      <div style="width:45%"></div>
    </div>
  </div>
</section>

<footer>
  <p>⚔ DRAGONWORLD — WHERE FIRE IS THE FIRST LANGUAGE ⚔</p>
</footer>

<script>
// ===== CURSOR DRAGON =====
const cursorDragon = document.getElementById('cursor-dragon');
const cursorTrail = document.getElementById('cursor-trail');
let mouseX = 0, mouseY = 0;
let lastX = 0, lastY = 0;

document.addEventListener('mousemove', (e) => {
  mouseX = e.clientX;
  mouseY = e.clientY;
  cursorDragon.style.left = mouseX + 'px';
  cursorDragon.style.top = mouseY + 'px';

  // Flip dragon to face direction of travel
  const dx = mouseX - lastX;
  if (Math.abs(dx) > 1) {
    // Dragon naturally faces LEFT (snout at left of SVG)
    // scaleX(1) = faces left, scaleX(-1) = faces right
    const flip = dx > 0 ? -1 : 1;
    cursorDragon.style.transform = `translate(-15px,-50px) scaleX(${flip})`;
  }
  lastX = mouseX; lastY = mouseY;

  createTrailParticle(mouseX, mouseY);
});

function createTrailParticle(x, y) {
  const p = document.createElement('div');
  p.className = 'trail-particle';
  const size = Math.random() * 6 + 4;
  p.style.cssText = `left:${x-size/2}px;top:${y-size/2}px;width:${size}px;height:${size}px;`;
  cursorTrail.appendChild(p);
  setTimeout(() => p.remove(), 600);
}

// ===== TAIL WAG ON CURSOR IDLE =====
let idleTimer;
const cursorTail = document.getElementById('cursor-tail');
document.addEventListener('mousemove', () => {
  clearTimeout(idleTimer);
  idleTimer = setTimeout(() => {
    cursorTail && cursorTail.animate([
      {transform:'rotate(0deg)',transformOrigin:'60% 50%'},
      {transform:'rotate(20deg)',transformOrigin:'60% 50%'},
      {transform:'rotate(-15deg)',transformOrigin:'60% 50%'},
      {transform:'rotate(10deg)',transformOrigin:'60% 50%'},
      {transform:'rotate(0deg)',transformOrigin:'60% 50%'}
    ], {duration:800, iterations:3});
  }, 2000);
});

// ===== SCROLL FIRE =====
const fireOverlay = document.getElementById('fire-overlay');
let isScrolling = false;
let scrollFireTimeout;
let scrollVelocity = 0;
let lastScrollY = window.scrollY;
let fireInterval;

window.addEventListener('scroll', () => {
  const currentY = window.scrollY;
  scrollVelocity = Math.abs(currentY - lastScrollY);
  lastScrollY = currentY;

  if (scrollVelocity > 5) {
    fireOverlay.classList.add('active');
    spawnFireParticles(scrollVelocity);
    clearTimeout(scrollFireTimeout);
    scrollFireTimeout = setTimeout(() => {
      fireOverlay.classList.remove('active');
    }, 300);
  }
});

function spawnFireParticles(intensity) {
  const count = Math.min(Math.floor(intensity / 3) + 3, 15);
  for (let i = 0; i < count; i++) {
    const p = document.createElement('div');
    p.className = 'fire-particle';
    const size = Math.random() * 40 + 20;
    const x = Math.random() * window.innerWidth;
    const startY = window.innerHeight * (0.5 + Math.random() * 0.5);
    const duration = 0.6 + Math.random() * 0.8;
    const hue = Math.random() < 0.5 ? '#ff4500' : Math.random() < 0.5 ? '#ff8c00' : '#ffd700';
    p.style.cssText = `
      left:${x}px;top:${startY}px;
      width:${size}px;height:${size * 1.5}px;
      background:radial-gradient(ellipse at 50% 80%,${hue},transparent);
      animation-duration:${duration}s;
    `;
    fireOverlay.appendChild(p);
    setTimeout(() => p.remove(), duration * 1000);
  }
}

// ===== FLOATING EMBERS =====
function createEmber() {
  const ember = document.createElement('div');
  ember.className = 'ember';
  const size = Math.random() * 4 + 2;
  const drift = (Math.random() - 0.5) * 200;
  const duration = 4 + Math.random() * 6;
  const delay = Math.random() * 5;
  ember.style.cssText = `
    width:${size}px;height:${size}px;
    left:${Math.random() * 100}%;
    bottom:-10px;
    --drift:${drift}px;
    animation-duration:${duration}s;
    animation-delay:${delay}s;
    opacity:0;
  `;
  document.body.appendChild(ember);
  setTimeout(() => ember.remove(), (duration + delay) * 1000 + 1000);
}
setInterval(createEmber, 400);
for (let i = 0; i < 10; i++) setTimeout(createEmber, i * 200);

// ===== WAVING ARM ON SCROLL =====
let lastWaveScroll = 0;
const waveArm = document.getElementById('cursor-arm');
window.addEventListener('scroll', () => {
  if (Math.abs(window.scrollY - lastWaveScroll) > 200) {
    lastWaveScroll = window.scrollY;
    if (waveArm) {
      waveArm.style.animation = 'none';
      waveArm.offsetHeight; // force reflow
      waveArm.style.animation = 'wave 0.4s ease-in-out 3';
    }
  }
});

// ===== PORTAL CLICK =====
const portalBtn = document.getElementById('dragon-mouth-portal');
const portalOverlay = document.getElementById('portal-overlay');
const closePortal = document.getElementById('close-portal');

portalBtn.addEventListener('click', () => {
  portalOverlay.classList.add('active');
  // Spawn lots of fire on enter
  for (let i = 0; i < 30; i++) {
    setTimeout(() => spawnFireParticles(30), i * 50);
  }
});
closePortal.addEventListener('click', () => {
  portalOverlay.classList.remove('active');
});

// ===== SCROLL REVEAL =====
const revealEls = document.querySelectorAll('.reveal, .timeline-item');
const observer = new IntersectionObserver((entries) => {
  entries.forEach(el => {
    if (el.isIntersecting) {
      el.target.classList.add('visible');
    }
  });
}, {threshold: 0.15});
revealEls.forEach(el => observer.observe(el));

// ===== MAIN DRAGON FLAME ANIMATION =====
const fireBreath = document.getElementById('fire-breath');
if (fireBreath) {
  setInterval(() => {
    fireBreath.animate([
      {opacity: 0.8, transform: 'scaleX(1) translateX(0)'},
      {opacity: 1, transform: 'scaleX(1.1) translateX(-5px)'},
      {opacity: 0.9, transform: 'scaleX(0.95) translateX(3px)'},
      {opacity: 1, transform: 'scaleX(1.05) translateX(-2px)'},
      {opacity: 0.8, transform: 'scaleX(1) translateX(0)'}
    ], {duration: 300, iterations: 1});
  }, 1200);
}

// ===== PARALLAX STARS =====
window.addEventListener('scroll', () => {
  const scrolled = window.scrollY;
  const stars = document.querySelector('.stars');
  if (stars) {
    stars.style.transform = `translateY(${scrolled * 0.3}px)`;
  }
});

// ===== SPECIES CARD CLICK WARP =====
document.querySelectorAll('.species-card').forEach(card => {
  card.addEventListener('click', () => {
    for (let i = 0; i < 20; i++) {
      setTimeout(() => spawnFireParticles(15), i * 30);
    }
  });
});
</script>
</body>
</html>
"""

headers_to_split_on=[("h1", "Header 1"), ("h2", "Header 2")]
html_splitter=HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
html_header_splitter=html_splitter.split_text(html_string)
html_header_splitter
# Out:
# [Document(metadata={}, page_content='Dragon cursor Fire overlay Portal overlay ===== HERO ===== ===== FIRE BREATH SECTION ===== ===== SPECIES SECTION ===== ===== PORTAL SECTION ===== ===== LEGENDS TIMELINE =====  \n=== WING (behind body) === Main wing membrane stretching up-right Wing membrane lower lobe Wing bone lines === TAIL === Tail spikes === BODY === Main torso - elongated dragon body Belly lighter scales === NECK === === HEAD === Skull/cranium Head top ridge / frill Forehead horn Secondary horn === SNOUT / JAW === Upper jaw - long pointed snout Lower jaw open slightly Teeth upper Teeth lower Nostril Fire breath from mouth === EYE === Vertical slit pupil Eye gleam Brow ridge === SPINE DORSAL SPIKES === === FRONT LEGS === Back leg Scale texture hints on body  \nFront leg left Claws'),
#  Document(metadata={'Header 2': "Inside the Dragon's Realm"}, page_content="Inside the Dragon's Realm"),
# ...

# %%
url='https://plato.stanford.edu/entries/goedel/'
headers_to_split_on=[('h1', 'Header 1'), ('h2', 'Header 2')]
html_splitter=HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
html_header_splitter=html_splitter.split_text_from_url(url)
html_header_splitter
# Out:
# C:\Users\moury\AppData\Local\Temp\ipykernel_28504\432213175.py:4: LangChainDeprecationWarning: Please fetch the HTML content from the URL yourself and pass it to split_text.
#   html_header_splitter=html_splitter.split_text_from_url(url)
# ...

# %% [markdown]
# ### JSON Splitter

# %%
import json
import requests

api='https://api.smith.langchain.com/openapi.json'

json_data=requests.get(api).json()

# %%
from langchain_text_splitters import RecursiveJsonSplitter

json_splitter=RecursiveJsonSplitter(max_chunk_size=300)
json_chunk=json_splitter.split_json(json_data)

# %%
for chunk in json_chunk[:3]:
    print(chunk)
# Out:
# {'openapi': '3.1.0', 'info': {'title': 'LangSmith', 'description': 'The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n'}}
# {'info': {'version': '0.1.0'}, 'paths': {'/api/v1/info': {'get': {'tags': ['info'], 'summary': 'Get Server Info', 'description': 'Get information about the current deployment of LangSmith.', 'operationId': 'get_server_info_api_v1_info_get'}}}}
# {'paths': {'/api/v1/info': {'get': {'responses': {'200': {'description': 'Successful Response', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/InfoGetResponse'}}}}}}}}}

# %%
docs=json_splitter.create_documents([json_data])
for doc in docs[:3]:
    print(doc)
# Out:
# page_content='{"openapi": "3.1.0", "info": {"title": "LangSmith", "description": "The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n"}}'
# page_content='{"info": {"version": "0.1.0"}, "paths": {"/api/v1/info": {"get": {"tags": ["info"], "summary": "Get Server Info", "description": "Get information about the current deployment of LangSmith.", "operationId": "get_server_info_api_v1_info_get"}}}}'
# page_content='{"paths": {"/api/v1/info": {"get": {"responses": {"200": {"description": "Successful Response", "content": {"application/json": {"schema": {"$ref": "#/components/schemas/InfoGetResponse"}}}}}}}}}'

# %%
texts=json_splitter.split_text(json_data)
for text in texts[:3]:
    print(text)
# Out:
# {"openapi": "3.1.0", "info": {"title": "LangSmith", "description": "The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n"}}
# {"info": {"version": "0.1.0"}, "paths": {"/api/v1/info": {"get": {"tags": ["info"], "summary": "Get Server Info", "description": "Get information about the current deployment of LangSmith.", "operationId": "get_server_info_api_v1_info_get"}}}}
# {"paths": {"/api/v1/info": {"get": {"responses": {"200": {"description": "Successful Response", "content": {"application/json": {"schema": {"$ref": "#/components/schemas/InfoGetResponse"}}}}}}}}}
