# %% [markdown]
# ## DuckDuckGo

# %%
from langchain_community.tools import DuckDuckGoSearchRun

tool=DuckDuckGoSearchRun()
results=tool.invoke("Hot news in Nizamabad")
results
# Out:
# 'Nizamabad photos, Archaeological and Heritage Museum - A front view - Nativeplanet /nizamabad/photos/3784/ ... Masjid_inn - Nativeplanet /nizamabad ... Nizamabad photos, Archaeological and Heritage Museum - A front view - Nativeplanet /nizamabad/photos/3784/ ... Masjid_inn - Nativeplanet /nizamabad ... Nizamabad photos, Archaeological and Heritage Museum - A front view - Nativeplanet /nizamabad/photos/3784/ ... Masjid_inn - Nativeplanet /nizamabad ... PC- Rizwanmahai One of the largest cities in Telangana, Nizamabad is also referred to as the city of Nizams on account of its history related to the ... Hyderabad Sankranti celebrations feature international kite festival, hot air balloons, and drone shows from January 13 to 18.'

# %% [markdown]
# ## Shell Tool

# %%
from langchain_community.tools import ShellTool

tool=ShellTool()

tool.invoke("nvidia-smi")
# Out:
# Executing command:
#  nvidia-smi
# ...
