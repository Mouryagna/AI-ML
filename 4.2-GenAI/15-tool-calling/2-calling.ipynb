# %%
from langchain_ollama import ChatOllama
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %%
@tool
def multiply(a:int,b:int)->int:
    """Given 2 numbers a and b this tool return their product"""
    return a*b

# %%
multiply.invoke({"a":5,"b":5})
# Out:
# 25

# %%
llm=ChatOllama(model="llama3.1")

# %%
llm_with_tools=llm.bind_tools([multiply])

# %%
llm_with_tools.invoke("hi")
# Out:
# AIMessage(content='I\'m not sure what you mean by "hi". Could you provide more context or clarify your question? \n\nAlso, the given prompt is empty. Please provide a valid question to get an accurate response.', additional_kwargs={}, response_metadata={'model': 'llama3.1', 'created_at': '2026-07-06T06:25:37.319687Z', 'done': True, 'done_reason': 'stop', 'total_duration': 11325609000, 'load_duration': 10211091700, 'prompt_eval_count': 165, 'prompt_eval_duration': 208913000, 'eval_count': 42, 'eval_duration': 869113000, 'logprobs': None, 'model_name': 'llama3.1', 'model_provider': 'ollama'}, id='lc_run--019f361a-5fe0-7142-b97a-85d46c06cf91-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 165, 'output_tokens': 42, 'total_tokens': 207})

# %%
llm_with_tools.invoke("what's 8 multiply to 7")
# Out:
# AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1', 'created_at': '2026-07-06T06:26:29.4477023Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1385378200, 'load_duration': 958018600, 'prompt_eval_count': 172, 'prompt_eval_duration': 19618000, 'eval_count': 22, 'eval_duration': 393452000, 'logprobs': None, 'model_name': 'llama3.1', 'model_provider': 'ollama'}, id='lc_run--019f361b-525d-7ba0-a994-7033d2155a09-0', tool_calls=[{'name': 'multiply', 'args': {'a': 8, 'b': 7}, 'id': '5c441bf8-4dd7-4704-a95e-45bd484ff4c8', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 172, 'output_tokens': 22, 'total_tokens': 194})

# %%
llm_with_tools.invoke("what's 8 multiply to 7").tool_calls[0]
# Out:
# {'name': 'multiply',
#  'args': {'b': 7, 'a': 8},
#  'id': '11c64056-915e-42f3-89e6-f0c46c5bf867',
#  'type': 'tool_call'}
