# %%
import pandas as pd

# %%
data = pd.read_csv("healthcare_dataset.csv")

# %%
data.head()
# Out:
#             Name   Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   NaN    Male         B-            Cancer        2024-01-31
# 1            NaN   NaN    Male         A+               NaN               NaN
# 2            NaN   NaN  Female        NaN           Obesity               NaN
# 3            NaN   NaN  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll  43.0  Female        NaN            Cancer        2022-09-19
#
#              Doctor         Hospital Insurance Provider  Billing Amount  \
# 0     Matthew Smith  Sons and Miller         Blue Cross    18856.281306
# 1               NaN          Kim Inc           Medicare    33643.327287
# 2  Tiffany Mitchell         Cook PLC              Aetna    27955.096079
# 3       Kevin Wells              NaN           Medicare    37909.782410
# 4    Kathleen Hanna      White-White              Aetna             NaN
#
# ...

# %%
data.tail()
# Out:
#                     Name   Age  Gender Blood Type Medical Condition  \
# 55495  eLIZABeTH jaCkSOn  42.0  Female        NaN            Asthma
# 55496         KYle pEREz  61.0  Female        AB-           Obesity
# 55497       HEATher WaNG  38.0  Female         B+               NaN
# 55498     JENniFER JOneS  43.0    Male         O-         Arthritis
# 55499                NaN   NaN  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 55495        2020-08-16    Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25              NaN                           NaN
# 55499        2024-04-02    Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
data.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  41280.000000    41371.000000  41393.000000
# mean      51.570615    25471.996106    301.273718
# std       19.639837    14205.269105    115.295924
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13142.422756    202.000000
# 50%       52.000000    25524.784827    302.000000
# 75%       68.000000    37690.177751    401.000000
# max       89.000000    52764.276736    500.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                41360 non-null  object
#  1   Age                 41280 non-null  float64
#  2   Gender              41467 non-null  object
#  3   Blood Type          41500 non-null  object
#  4   Medical Condition   41321 non-null  object
#  5   Date of Admission   41428 non-null  object
#  6   Doctor              41398 non-null  object
#  7   Hospital            41569 non-null  object
#  8   Insurance Provider  41513 non-null  object
#  9   Billing Amount      41371 non-null  float64
#  10  Room Number         41393 non-null  float64
#  11  Admission Type      41248 non-null  object
#  12  Discharge Date      41448 non-null  object
#  13  Medication          41388 non-null  object
#  14  Test Results        55500 non-null  object
# dtypes: float64(3), object(12)
# ...

# %%
threshold = data.shape[1]*0.4

# %%
threshold
# Out:
# 6.0

# %%
data.to_csv("cleaned_copy.csv")

# %%
row_null_ratio = data.isna().sum(axis=1)
count = (row_null_ratio> threshold).sum()

# %%
count
# Out:
# np.int64(4531)

# %%
data[row_null_ratio> threshold]
# Out:
#                      Name   Age  Gender Blood Type Medical Condition  \
# 1                     NaN   NaN    Male         A+               NaN
# 16                    NaN   NaN     NaN         A+               NaN
# 19         dANIEL schmIdt  63.0    Male        NaN               NaN
# 36          DEnIse ToRRES  33.0     NaN        AB+          Diabetes
# 37     CasSAndrA Robinson  26.0  Female         B-      Hypertension
# ...                   ...   ...     ...        ...               ...
# 55464                 NaN  35.0  Female        AB-               NaN
# 55472                 NaN   NaN     NaN        AB-               NaN
# 55476                 NaN  31.0  Female        NaN               NaN
# 55479                 NaN   NaN     NaN         B-            Cancer
# 55485                 NaN  41.0  Female        NaN            Asthma
#
#       Date of Admission          Doctor         Hospital Insurance Provider  \
# ...

# %%
data.dropna(thres=threshold)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 data.dropna(thres=threshold)
#
# TypeError: DataFrame.dropna() got an unexpected keyword argument 'thres'

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["A", "B"],
    "Math": [90, 80],
    "Science": [85, 75]
})

melted = pd.melt(df, id_vars=["Name"], var_name="Subject", value_name="Marks")
print(melted)
# Out:
#   Name  Subject  Marks
# 0    A     Math     90
# 1    B     Math     80
# 2    A  Science     85
# 3    B  Science     75
